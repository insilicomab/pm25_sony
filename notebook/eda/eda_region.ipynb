# %%
# Googleドライブマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # データの読み込みと確認

# %%
# 提出ファイル名
sub_name = 'pm_region'

# 削除するカラム
del_columns = ['pm25_mid', 'id']

# %%
# ライブラリのインポート
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# ランダムシードの設定
import random
np.random.seed(1234)
random.seed(1234)

# データの読み込み
train = pd.read_csv('/content/drive/MyDrive/pm/data/input/train.csv')
test = pd.read_csv('/content/drive/MyDrive/pm/data/input/test.csv')
submission = pd.read_csv('/content/drive/MyDrive/pm/data/input/submit_sample.csv', header=None)

# %%
# 学習データとテストデータの連結
df = pd.concat([train, test], sort=False).reset_index(drop=True)

# %% [markdown]
# # 国と都市の確認用データフレーム

# %%
df_cc = df.copy()

# %%
df_cc['Country-City'] = df_cc['Country']+' - '+df_cc['City']

# %%
# trainとtestに再分割
train_cc = df_cc[~df_cc['pm25_mid'].isnull()]
test_cc = df_cc[df_cc['pm25_mid'].isnull()]

# %%
# 学習データの国と都市の組み合わせを確認
train_cc['Country-City'].unique()
# Out:
# array(['Australia - Brisbane', 'Australia - Darwin',
#        'Australia - Melbourne', 'Australia - Newcastle',
#        'Australia - Perth', 'Australia - Wollongong',
#        'Belgium - Antwerpen', 'Belgium - Charleroi', 'Belgium - Liège',
#        'Brazil - São Paulo', 'Brazil - Vitória', 'Canada - Vancouver',
#        'Chile - Calama', 'Chile - Quilpué', 'Chile - Talca',
#        'China - Beijing', 'China - Changsha', 'China - Chengdu',
#        'China - Foshan', 'China - Fushun', 'China - Fuzhou',
#        'China - Guangzhou', 'China - Guiyang', 'China - Haikou',
#        'China - Hangzhou', 'China - Harbin', 'China - Hefei',
#        'China - Hegang', 'China - Jieyang', 'China - Jinan',
#        'China - Kunming', 'China - Lhasa', 'China - Nanchang',
#        'China - Nanjing', 'China - Nanning', 'China - Ningbo',
#        'China - Qingdao', 'China - Qinhuangdao', 'China - Qiqihar',
#        'China - Shantou', 'China - Shenzhen', 'China - Suzhou',
#        'China - Taiyuan', 'China - Xiamen', 'China - Xining',
#        'China - Xinxiang', 'China - Xi’an', 'China - Yinchuan',
#        'China - Yunfu', 'China - Zhengzhou', 'China - Zhuzhou',
#        'China - Ürümqi', 'France - Marseille', 'France - Nancy',
#        'France - Nantes', 'France - Strasbourg', 'Germany - Berlin',
#        'Germany - Hamburg', 'Hungary - Budapest', 'Hungary - Győr',
#        'Hungary - Miskolc', 'Hungary - Pécs', 'Hungary - Szeged',
#        'India - Bengaluru', 'India - Bhopal', 'India - Chandigarh',
#        'India - Delhi', 'India - Gandhinagar', 'India - Hyderabad',
#        'India - Hāpur', 'India - Jaipur', 'India - Kolkata',
#        'India - Mumbai', 'India - Muzaffarnagar',
#        'India - Thiruvananthapuram', 'India - Thrissur',
#        'India - Visakhapatnam', 'Iran - Yazd', 'Israel - Netanya',
#        'Israel - Tel Aviv', 'Italy - Brescia', 'Italy - Livorno',
#        'Italy - Milan', 'Italy - Naples', 'Italy - Rome', 'Japan - Akita',
#        'Japan - Chiba', 'Japan - Fukuoka', 'Japan - Gifu-shi',
#        'Japan - Hiroshima', 'Japan - Kagoshima', 'Japan - Kanazawa',
#        'Japan - Kobe', 'Japan - Kochi', 'Japan - Kyoto',
#        'Japan - Miyazaki', 'Japan - Nagasaki', 'Japan - Naha',
#        'Japan - Nara-shi', 'Japan - Okayama', 'Japan - Sapporo',
#        'Japan - Sendai', 'Japan - Shizuoka', 'Japan - Tokyo',
#        'Japan - Toyama', 'Japan - Utsunomiya', 'Japan - Wakayama',
#        'Japan - Ōita', 'Mexico - Guadalajara', 'Mexico - Monterrey',
#        'Mexico - Oaxaca', 'Mexico - Pachuca de Soto',
#        'Mexico - San Luis Potosí', 'Mexico - Tepic', 'Mexico - Toluca',
#        'Poland - Bydgoszcz', 'Poland - Gdańsk', 'Poland - Kraków',
#        'Poland - Poznań', 'Poland - Szczecin', 'Poland - Wrocław',
#        'Poland - Łódź', 'Russia - Nizhniy Novgorod', 'Serbia - Niš',
#        'South Africa - East London', 'South Africa - Middelburg',
#        'South Africa - Vereeniging', 'South Africa - Worcester',
#        'South Korea - Andong', 'South Korea - Busan',
#        'South Korea - Changwon', 'South Korea - Cheongju-si',
#        'South Korea - Chuncheon', 'South Korea - Daejeon',
#        'South Korea - Gwangju', 'South Korea - Incheon',
#        'South Korea - Jeju City', 'South Korea - Mokpo',
#        'South Korea - Pohang', 'South Korea - Seongnam-si',
#        'South Korea - Seoul', 'South Korea - Suncheon',
#        'South Korea - Ulsan', 'Spain - Barcelona', 'Spain - Bilbao',
#        'Spain - Gasteiz / Vitoria', 'Spain - Madrid', 'Spain - Oviedo',
#        'Spain - Palma', 'Spain - Salamanca', 'Spain - Valencia',
#        'Taiwan - Hsinchu', 'Taiwan - Kaohsiung', 'Taiwan - Keelung',
#        'Taiwan - Taichung', 'Taiwan - Taipei', 'Taiwan - Taitung City',
#        'Taiwan - Taoyuan City', 'Thailand - Bangkok',
#        'Thailand - Chiang Mai', 'Thailand - Chon Buri',
#        'Thailand - Nakhon Pathom', 'Thailand - Rayong',
#        'Turkey - Adapazarı', 'Turkey - Antakya', 'Turkey - Balıkesir',
#        'Turkey - Erzurum', 'Turkey - Eskişehir', 'Turkey - Istanbul',
#        'Turkey - Kayseri', 'Turkey - Konya', 'Turkey - Kütahya',
#        'Turkey - Samsun', 'Turkey - İzmit', 'United Kingdom - Belfast',
#        'United Kingdom - Edinburgh', 'United Kingdom - Leeds',
#        'United States - Albuquerque', 'United States - Boise',
#        'United States - Jackson', 'United States - Jacksonville',
#        'United States - Las Vegas', 'United States - Los Angeles',
#        'United States - Milwaukee', 'United States - Phoenix',
#        'United States - Saint Paul', 'Vietnam - Hanoi',
#        'Vietnam - Hạ Long', 'China - Changzhou', 'China - Shanghai',
#        'Iran - Sanandaj', 'Iran - Tehran', 'Israel - Haifa',
#        'Japan - Nagano', 'Japan - Takamatsu', 'Japan - Yokohama',
#        'Mexico - Morelia', 'Poland - Tarnów', 'Poland - Warsaw',
#        'Russia - Saint Petersburg', 'South Korea - Yeosu',
#        'Spain - Granada', 'Spain - Huelva',
#        'Spain - Las Palmas de Gran Canaria',
#        'United States - Indianapolis', 'United States - Raleigh',
#        'Germany - Mainz', 'Iran - Khorramabad', 'Iran - Tabriz',
#        'Netherlands - Haarlem', 'Serbia - Novi Sad',
#        'United States - San Jose', 'Mexico - Puebla',
#        'United States - Oklahoma City', 'Chile - Los Ángeles',
#        'Iran - Qom', 'Iran - Zanjān', 'Mexico - Chihuahua',
#        'United Kingdom - Cardiff', 'Vietnam - Huế',
#        'Bosnia and Herzegovina - Zenica', 'India - Chennai',
#        'Belgium - Gent', 'United States - Atlanta', 'Croatia - Zagreb',
#        'Iran - Bandar Abbas', 'India - Shillong',
#        'United Kingdom - Southend-on-Sea', 'India - Patna',
#        'Thailand - Lampang', 'India - Lucknow', 'Russia - Novosibirsk',
#        'Poland - Kielce', 'United States - Detroit',
#        'United States - Denver', 'South Africa - Pretoria',
#        'Israel - Jerusalem', 'United States - El Paso',
#        'Bosnia and Herzegovina - Tuzla'], dtype=object)

# %%
# テストデータの国と都市の組み合わせを確認
print(test_cc['Country-City'].unique())
print(test_cc['Country-City'].nunique())
# Out:
# ['Australia - Adelaide' 'Australia - Sydney' 'Belgium - Brussels'
#  'Bosnia and Herzegovina - Sarajevo' 'Brazil - São José dos Campos'
#  'Canada - Surrey' 'Chile - Concepción' 'Chile - Santiago'
#  'China - Changchun' 'China - Chongqing' 'China - Dongguan'
#  'China - Lanzhou' 'China - Shenyang' 'China - Shijiazhuang'
#  'China - Wuhan' 'China - Wuxi' 'China - Xuchang' 'Croatia - Rijeka'
#  'France - Paris' 'Hungary - Kecskemét' 'India - Ghāziābād'
#  'India - Mysore' 'India - Nagpur' 'Israel - Petaẖ Tiqwa'
#  'Japan - Matsuyama' 'Japan - Nagoya' 'Japan - Niigata' 'Japan - Osaka'
#  'Mexico - Cuernavaca' 'Mexico - Mexico City' 'Netherlands - Amsterdam'
#  'Poland - Płock' 'Russia - Moscow' 'Serbia - Belgrade'
#  'South Africa - Port Elizabeth' 'South Korea - Daegu'
#  'South Korea - Jeonju' 'South Korea - Sejong' 'South Korea - Suwon'
#  'Spain - Burgos' 'Taiwan - Douliu' 'Taiwan - Tainan'
#  'Thailand - Samut Prakan' 'Turkey - Bursa' 'Turkey - Trabzon'
#  'United Kingdom - London' 'United States - Chicago'
#  'United States - Fresno' 'United States - Tucson' 'Vietnam - Haiphong'
#  'Japan - Kumamoto' 'Japan - Saitama' 'Spain - Santa Cruz de Tenerife'
#  'United States - Charlotte' 'China - Anyang' 'Iran - Karaj'
#  'Poland - Katowice' 'Spain - Málaga' 'Turkey - Adana' 'Germany - Potsdam'
#  'India - Nashik' 'Italy - Parma' 'South Africa - Johannesburg']
# 63

# %% [markdown]
# # testのCityを近隣都市に置き換えたときのスコアの推移の確認

# %%
# ユニークな都市の数
print('ユニークな都市の数: ', df['City'].nunique())
# Out:
# ユニークな都市の数:  302

# %% [markdown]
# # イタリア
# Parma→Brescia

# %%
# イタリア
df['City'].replace({'Parma': 'Brescia'}, inplace=True)

# %% [markdown]
# # ドイツ
# Potsdam→Berlin

# %%
# ドイツ
df['City'].replace({'Potsdam': 'Berlin'}, inplace=True)

# %% [markdown]
# # イラン
# Karaj→Tehran

# %%
# イラン
df['City'].replace({'Karaj': 'Tehran'}, inplace=True)

# %% [markdown]
# # ベトナム
# Haiphong→Hạ Long

# %%
# ベトナム
df['City'].replace({'Haiphong': 'Hạ Long'}, inplace=True)

# %% [markdown]
# # アメリカ
# Chicago→Jackson
# Fresno→San Jose
# Tucson→Albuquerque
# Charlotte→Raleigh

# %%
# アメリカ
df['City'].replace({'Chicago': 'Jackson', 
                    'Fresno':'San Jose',
                    'Tucson': 'Albuquerque',
                    'Charlotte': 'Raleigh'
                    }, inplace=True)

# %% [markdown]
# # イギリス
# London→Southend-on-Sea

# %%
# イギリス
df['City'].replace({'London': 'Southend-on-Sea'}, inplace=True)

# %% [markdown]
# # トルコ
# Bursa→İzmit
# Trabzon→Samsun
# Adana→Antakya

# %%
# トルコ
df['City'].replace({'Bursa': 'İzmit', 
                    'Trabzon':'Samsun',
                    'Adana': 'Antakya'
                    }, inplace=True)

# %% [markdown]
# # タイ
# Samut Prakan→Bangkok

# %%
# タイ
df['City'].replace({'Samut Prakan': 'Bangkok'}, inplace=True)

# %% [markdown]
# # 台湾
# Douliu→Taichung
# Tainan→Kaohsiung

# %%
# 台湾
df['City'].replace({'Douliu': 'Taichung', 
                    'Tainan':'Kaohsiung',
                    }, inplace=True)

# %% [markdown]
# # スペイン
# Burgos→Gasteiz / Vitoria
# Santa Cruz de Tenerife→Las Palmas de Gran Canaria
# Málaga→Granada

# %%
# スペイン
df['City'].replace({'Burgos': 'Gasteiz / Vitoria', 
                    'Santa Cruz de Tenerife':'Las Palmas de Gran Canaria',
                    'Málaga': 'Granada'
                    }, inplace=True)

# %% [markdown]
# # 韓国
# Daegu→Pohang
# Jeonju→Daejeon
# Sejong→Cheongju-si
# Suwon→Seoul

# %%
# 韓国
df['City'].replace({'Daegu': 'Pohang', 
                    'Jeonju':'Daejeon',
                    'Sejong': 'Cheongju-si',
                    'Suwon': 'Seoul'
                    }, inplace=True)

# %% [markdown]
# # 南アフリカ
# Port Elizabeth→East London
# Johannesburg→Pretoria

# %%
# 南アフリカ
df['City'].replace({'Port Elizabeth': 'East London', 'Johannesburg': 'Pretoria'}, inplace=True)

# %% [markdown]
# # セルビア
# Belgrade→Novi Sad

# %%
# セルビア
df['City'].replace({'Belgrade': 'Novi Sad'}, inplace=True)

# %% [markdown]
# # ロシア
# Moscow→Nizhniy Novgorod

# %%
# ロシア
df['City'].replace({'Moscow': 'Nizhniy Novgorod'}, inplace=True)

# %% [markdown]
# # ポーランド
# Płock→Łódź
# Katowice→Kraków

# %%
# ポーランド
df['City'].replace({'Płock': 'Łódź', 'Katowice': 'Kraków'}, inplace=True)

# %% [markdown]
# # オランダ
# Amsterdam→Haarlem

# %%
# オランダ
df['City'].replace({'Amsterdam': 'Haarlem'}, inplace=True)

# %% [markdown]
# # メキシコ
# Cuernavaca→Toluca
# Mexico City→Toluca

# %%
# メキシコ
df['City'].replace({'Cuernavaca': 'Toluca', 'Mexico City': 'Toluca'}, inplace=True)

# %% [markdown]
# # イスラエル
# Petaẖ Tiqwa→Netanya

# %%
# イスラエル
df['City'].replace({'Petaẖ Tiqwa': 'Netanya'}, inplace=True)

# %% [markdown]
# # インド
# Ghāziābād→Delhi
# Mysore→Bengaluru
# Nagpur→Bhopal
# Nashik→Mumbai

# %%
# インド
df['City'].replace({'Ghāziābād': 'Delhi', 'Mysore':'Bengaluru', 'Nagpur':'Bhopal', 'Nashik': 'Mumbai'}, inplace=True)

# %% [markdown]
# # ハンガリー
# Kecskemét→Budapest

# %%
# ハンガリー
df['City'].replace({'Kecskemét': 'Budapest'}, inplace=True)

# %% [markdown]
# # フランス
# Paris→Nancy

# %%
# フランス
df['City'].replace({'Paris': 'Nancy'}, inplace=True)

# %% [markdown]
# # 中国
# Changchun→Fushun
# Chongqing→Chengdu
# Dongguan→Foshan
# Lanzhou→Xining
# Shenyang→Fushun
# Shijiazhuang→Jinan
# Wuhan→Changsha
# Wuxi→Zhuzhou
# Xuchang→Zhengzhou
# Anyang→Zhengzhou

# %%
# 中国
df['City'].replace({'Changchun': 'Fushun', 
                    'Chongqing':'Chengdu',
                    'Dongguan': 'Foshan',
                    'Lanzhou': 'Xining',
                    'Shenyang': 'Fushun',
                    'Shijiazhuang': 'Jinan',
                    'Wuhan': 'Changsha',
                    'Wuxi': 'Zhuzhou',
                    'Xuchang': 'Zhengzhou',
                    'Anyang': 'Zhengzhou'
                    }, inplace=True)

# %% [markdown]
# # クロアチア
# Rijeka→Zagreb

# %%
# クロアチア
df['City'].replace({'Rijeka': 'Zagreb'}, inplace=True)

# %% [markdown]
# # チリ
# Concepción→Talca
# Santiago→Quilpué

# %%
# チリ
df['City'].replace({'Concepción': 'Talca', 'Santiago': 'Quilpué'}, inplace=True)

# %% [markdown]
# # カナダ
# Surrey→Vancouver

# %%
# カナダ
df['City'].replace({'Surrey': 'Vancouver'}, inplace=True)

# %% [markdown]
# # ボスニア・ヘルツェゴビナ
# Sarajevo→Zenica

# %%
# ボスニア・ヘルツェゴビナ
df['City'].replace({'Sarajevo': 'Zenica'}, inplace=True)

# %% [markdown]
# # ブラジル
# São José dos Campos→São Paulo

# %%
# ブラジル
df['City'].replace({'São José dos Campos': 'São Paulo'}, inplace=True)

# %% [markdown]
# # ベルギー
# Brussels→Antwerpen

# %%
# ベルギー
df['City'].replace({'Brussels': 'Antwerpen'}, inplace=True)

# %% [markdown]
# # 日本
# Nagoya→Gifu-shi
# Matsuyama→Hiroshima
# Niigata→Kanazawa
# Osaka→Kyoto
# Kumamoto→Ōita
# Saitama→Tokyo

# %%
# 日本
df['City'].replace({'Matsuyama': 'Hiroshima', 'Nagoya': 'Gifu-shi', 'Niigata': 'Kanazawa', 'Osaka': 'Kyoto', 'Kumamoto': 'Ōita', 'Saitama': 'Tokyo'}, inplace=True)

# %% [markdown]
# # オーストラリア
# Adelaide→Melbourne
# Sydney→Wollongong

# %%
# オーストラリア
df['City'].replace({'Adelaide': 'Melbourne', 'Sydney': 'Wollongong'}, inplace=True)

# %%
print(df['City'].unique(),'ユニークな都市の数（変換後）: ',  df['City'].nunique())
# Out:
# ['Brisbane' 'Darwin' 'Melbourne' 'Newcastle' 'Perth' 'Wollongong'
#  'Antwerpen' 'Charleroi' 'Liège' 'São Paulo' 'Vitória' 'Vancouver'
#  'Calama' 'Quilpué' 'Talca' 'Beijing' 'Changsha' 'Chengdu' 'Foshan'
#  'Fushun' 'Fuzhou' 'Guangzhou' 'Guiyang' 'Haikou' 'Hangzhou' 'Harbin'
#  'Hefei' 'Hegang' 'Jieyang' 'Jinan' 'Kunming' 'Lhasa' 'Nanchang' 'Nanjing'
#  'Nanning' 'Ningbo' 'Qingdao' 'Qinhuangdao' 'Qiqihar' 'Shantou' 'Shenzhen'
#  'Suzhou' 'Taiyuan' 'Xiamen' 'Xining' 'Xinxiang' 'Xi’an' 'Yinchuan'
#  'Yunfu' 'Zhengzhou' 'Zhuzhou' 'Ürümqi' 'Marseille' 'Nancy' 'Nantes'
#  'Strasbourg' 'Berlin' 'Hamburg' 'Budapest' 'Győr' 'Miskolc' 'Pécs'
#  'Szeged' 'Bengaluru' 'Bhopal' 'Chandigarh' 'Delhi' 'Gandhinagar'
#  'Hyderabad' 'Hāpur' 'Jaipur' 'Kolkata' 'Mumbai' 'Muzaffarnagar'
#  'Thiruvananthapuram' 'Thrissur' 'Visakhapatnam' 'Yazd' 'Netanya'
#  'Tel Aviv' 'Brescia' 'Livorno' 'Milan' 'Naples' 'Rome' 'Akita' 'Chiba'
#  'Fukuoka' 'Gifu-shi' 'Hiroshima' 'Kagoshima' 'Kanazawa' 'Kobe' 'Kochi'
#  'Kyoto' 'Miyazaki' 'Nagasaki' 'Naha' 'Nara-shi' 'Okayama' 'Sapporo'
#  'Sendai' 'Shizuoka' 'Tokyo' 'Toyama' 'Utsunomiya' 'Wakayama' 'Ōita'
#  'Guadalajara' 'Monterrey' 'Oaxaca' 'Pachuca de Soto' 'San Luis Potosí'
#  'Tepic' 'Toluca' 'Bydgoszcz' 'Gdańsk' 'Kraków' 'Poznań' 'Szczecin'
#  'Wrocław' 'Łódź' 'Nizhniy Novgorod' 'Niš' 'East London' 'Middelburg'
#  'Vereeniging' 'Worcester' 'Andong' 'Busan' 'Changwon' 'Cheongju-si'
#  'Chuncheon' 'Daejeon' 'Gwangju' 'Incheon' 'Jeju City' 'Mokpo' 'Pohang'
#  'Seongnam-si' 'Seoul' 'Suncheon' 'Ulsan' 'Barcelona' 'Bilbao'
#  'Gasteiz / Vitoria' 'Madrid' 'Oviedo' 'Palma' 'Salamanca' 'Valencia'
#  'Hsinchu' 'Kaohsiung' 'Keelung' 'Taichung' 'Taipei' 'Taitung City'
#  'Taoyuan City' 'Bangkok' 'Chiang Mai' 'Chon Buri' 'Nakhon Pathom'
#  'Rayong' 'Adapazarı' 'Antakya' 'Balıkesir' 'Erzurum' 'Eskişehir'
#  'Istanbul' 'Kayseri' 'Konya' 'Kütahya' 'Samsun' 'İzmit' 'Belfast'
#  'Edinburgh' 'Leeds' 'Albuquerque' 'Boise' 'Jackson' 'Jacksonville'
#  'Las Vegas' 'Los Angeles' 'Milwaukee' 'Phoenix' 'Saint Paul' 'Hanoi'
#  'Hạ Long' 'Changzhou' 'Shanghai' 'Sanandaj' 'Tehran' 'Haifa' 'Nagano'
#  'Takamatsu' 'Yokohama' 'Morelia' 'Tarnów' 'Warsaw' 'Saint Petersburg'
#  'Yeosu' 'Granada' 'Huelva' 'Las Palmas de Gran Canaria' 'Indianapolis'
#  'Raleigh' 'Mainz' 'Khorramabad' 'Tabriz' 'Haarlem' 'Novi Sad' 'San Jose'
#  'Puebla' 'Oklahoma City' 'Los Ángeles' 'Qom' 'Zanjān' 'Chihuahua'
#  'Cardiff' 'Huế' 'Zenica' 'Chennai' 'Gent' 'Atlanta' 'Zagreb'
#  'Bandar Abbas' 'Shillong' 'Southend-on-Sea' 'Patna' 'Lampang' 'Lucknow'
#  'Novosibirsk' 'Kielce' 'Detroit' 'Denver' 'Pretoria' 'Jerusalem'
#  'El Paso' 'Tuzla'] ユニークな都市の数（変換後）:  239

# %%
# object型の変数の取得
categories = df.columns[df.dtypes == 'object']
print(categories)

# label Encoding
for cat in categories:
    le = LabelEncoder() 
    print(cat)
    
    df[cat].fillna('missing', inplace=True)
    le = le.fit(df[cat])
    df[cat] = le.transform(df[cat])
    # LabelEncoderは数値に変換するだけであるため、最後にastype('category')としておく
    df[cat] = df[cat].astype('category')
# Out:
# Index(['Country', 'City'], dtype='object')
# Country
# City

# %%
# trainとtestに再分割
train = df[~df['pm25_mid'].isnull()]
test = df[df['pm25_mid'].isnull()]

# %%
print(train.columns, len(train.columns))
# Out:
# Index(['id', 'year', 'month', 'day', 'Country', 'City', 'lat', 'lon', 'co_cnt',
#        'co_min', 'co_mid', 'co_max', 'co_var', 'o3_cnt', 'o3_min', 'o3_mid',
#        'o3_max', 'o3_var', 'so2_cnt', 'so2_min', 'so2_mid', 'so2_max',
#        'so2_var', 'no2_cnt', 'no2_min', 'no2_mid', 'no2_max', 'no2_var',
#        'temperature_cnt', 'temperature_min', 'temperature_mid',
#        'temperature_max', 'temperature_var', 'humidity_cnt', 'humidity_min',
#        'humidity_mid', 'humidity_max', 'humidity_var', 'pressure_cnt',
#        'pressure_min', 'pressure_mid', 'pressure_max', 'pressure_var',
#        'ws_cnt', 'ws_min', 'ws_mid', 'ws_max', 'ws_var', 'dew_cnt', 'dew_min',
#        'dew_mid', 'dew_max', 'dew_var', 'pm25_mid'],
#       dtype='object') 54

# %% [markdown]
# # モデルの構築と評価

# %%
# ライブラリのインポート
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from statistics import mean

# K分割する
folds = 20
kf = KFold(n_splits=folds)

# ハイパーパラメータの設定
params = {
    'objective':'regression',
    'random_seed':1234, 
}

# 説明変数と目的変数を指定
X_train = train.drop(del_columns, axis=1)
Y_train = train['pm25_mid']

# 各foldごとに作成したモデルごとの予測値を保存
models = []
rmses = []

for train_index, val_index in kf.split(X_train):
    x_train = X_train.iloc[train_index]
    x_valid = X_train.iloc[val_index]
    y_train = Y_train.iloc[train_index]
    y_valid = Y_train.iloc[val_index]
    
    lgb_train = lgb.Dataset(x_train, y_train)
    lgb_eval = lgb.Dataset(x_valid, y_valid, reference=lgb_train)    
    
    model = lgb.train(params,
                      lgb_train, 
                      valid_sets=lgb_eval, 
                      num_boost_round=1000, # 学習回数の実行回数
                      early_stopping_rounds=20, # early_stoppingの判定基準
                      verbose_eval=10)
    
    y_pred = model.predict(x_valid, num_iteration=model.best_iteration)
    rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
    print(rmse)
    
    models.append(model)
    rmses.append(rmse)

# 平均AUCを計算する
print(mean(rmses))

# 特徴量重要度の表示
for model in models:
    lgb.plot_importance(model, importance_type='gain',
                        figsize=(10, 15),
                        max_num_features=len(train.columns))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # テストデータの予測

# %%
# テストデータの説明変数を指定
X_test = test.drop(del_columns, axis=1)
print(X_test.columns)

# テストデータにおける予測
preds = []

for model in models:
    pred = model.predict(X_test)
    preds.append(pred)

# predsの平均を計算
preds_array = np.array(preds)
preds_mean = np.mean(preds_array, axis=0)
# Out:
# Index(['year', 'month', 'day', 'Country', 'City', 'lat', 'lon', 'co_cnt',
#        'co_min', 'co_mid', 'co_max', 'co_var', 'o3_cnt', 'o3_min', 'o3_mid',
#        'o3_max', 'o3_var', 'so2_cnt', 'so2_min', 'so2_mid', 'so2_max',
#        'so2_var', 'no2_cnt', 'no2_min', 'no2_mid', 'no2_max', 'no2_var',
#        'temperature_cnt', 'temperature_min', 'temperature_mid',
#        'temperature_max', 'temperature_var', 'humidity_cnt', 'humidity_min',
#        'humidity_mid', 'humidity_max', 'humidity_var', 'pressure_cnt',
#        'pressure_min', 'pressure_mid', 'pressure_max', 'pressure_var',
#        'ws_cnt', 'ws_min', 'ws_mid', 'ws_max', 'ws_var', 'dew_cnt', 'dew_min',
#        'dew_mid', 'dew_max', 'dew_var'],
#       dtype='object')

# %% [markdown]
# # 提出

# %%
# 値を置き換え
submission[1] = preds_mean

# CSVファイルの出力
submission.to_csv(f'/content/drive/MyDrive/pm/submit/{sub_name}.csv', header=None, index=False)
